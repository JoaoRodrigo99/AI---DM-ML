# %%
# Data processing
import pandas as pd
import numpy as np
import scipy.stats

# Visualization
import seaborn as sb

# Similarity
from sklearn.metrics.pairwise import cosine_similarity

# %%
ratings = pd.read_csv("./archive/rating_complete.csv")
# ratings_reduced = ratings.sample(frac=0.01)
ratings.head()
# Out:
#    user_id  anime_id  rating
# 0        0       430       9
# 1        0      1004       5
# 2        0      3010       7
# 3        0       570       7
# 4        0      2762       9

# %%
anime_df = pd.read_csv("./archive/anime.csv")
anime_df["anime_id"] = anime_df["MAL_ID"]
anime_df.head()
# Out:
#    MAL_ID                             Name Score  \
# 0       1                     Cowboy Bebop  8.78
# 1       5  Cowboy Bebop: Tengoku no Tobira  8.39
# 2       6                           Trigun  8.24
# 3       7               Witch Hunter Robin  7.27
# 4       8                   Bouken Ou Beet  6.98
#
#                                               Genres            English name  \
# 0    Action, Adventure, Comedy, Drama, Sci-Fi, Space            Cowboy Bebop
# 1              Action, Drama, Mystery, Sci-Fi, Space  Cowboy Bebop:The Movie
# 2  Action, Sci-Fi, Adventure, Comedy, Drama, Shounen                  Trigun
# 3  Action, Mystery, Police, Supernatural, Drama, ...      Witch Hunter Robin
# 4          Adventure, Fantasy, Shounen, Supernatural  Beet the Vandel Buster
#
#                       Japanese name   Type Episodes  \
# 0                         カウボーイビバップ     TV       26
# 1                    カウボーイビバップ 天国の扉  Movie        1
# 2                             トライガン     TV       26
# 3  Witch Hunter ROBIN (ウイッチハンターロビン)     TV       26
# 4                            冒険王ビィト     TV       52
#
#                           Aired    Premiered  ...   Score-9   Score-8  \
# 0   Apr 3, 1998 to Apr 24, 1999  Spring 1998  ...  182126.0  131625.0
# 1                   Sep 1, 2001      Unknown  ...   49201.0   49505.0
# 2   Apr 1, 1998 to Sep 30, 1998  Spring 1998  ...   75651.0   86142.0
# 3   Jul 2, 2002 to Dec 24, 2002  Summer 2002  ...    4806.0   10128.0
# 4  Sep 30, 2004 to Sep 29, 2005    Fall 2004  ...     529.0    1242.0
#
#    Score-7  Score-6 Score-5 Score-4 Score-3  Score-2  Score-1  anime_id
# 0  62330.0  20688.0  8904.0  3184.0  1357.0    741.0   1580.0         1
# 1  22632.0   5805.0  1877.0   577.0   221.0    109.0    379.0         5
# 2  49432.0  15376.0  5838.0  1965.0   664.0    316.0    533.0         6
# 3  11618.0   5709.0  2920.0  1083.0   353.0    164.0    131.0         7
# 4   1713.0   1068.0   634.0   265.0    83.0     50.0     27.0         8
#
# [5 rows x 36 columns]

# %%
df = pd.merge(ratings, anime_df[['anime_id','Name', 'Genres']], on="anime_id", how="inner")
# df = ratings_reduced.merge(anime_df[['Name', 'Genres']])
df
# Out:
#           user_id  anime_id  rating  \
# 0               0       430       9
# 1               6       430       8
# 2              18       430      10
# 3              19       430       8
# 4              33       430       4
# ...           ...       ...     ...
# 57633273   315549     38853       1
# 57633274   350024     38853      10
# 57633275   311855     39435       6
# 57633276   334473     35746       4
# 57633277   347134     39627       5
#
#                                                      Name  \
# 0         Fullmetal Alchemist: The Conqueror of Shamballa
# 1         Fullmetal Alchemist: The Conqueror of Shamballa
# 2         Fullmetal Alchemist: The Conqueror of Shamballa
# 3         Fullmetal Alchemist: The Conqueror of Shamballa
# 4         Fullmetal Alchemist: The Conqueror of Shamballa
# ...                                                   ...
# 57633273                                           Ex-Arm
# 57633274                                           Ex-Arm
# 57633275          Oshiri Tantei Movie 1: Curry Naru Jiken
# 57633276                                         6 Lovers
# 57633277                        Nan-chan no Koutsuu Anzen
#
#                                                      Genres
# 0         Military, Comedy, Historical, Drama, Fantasy, ...
# 1         Military, Comedy, Historical, Drama, Fantasy, ...
# 2         Military, Comedy, Historical, Drama, Fantasy, ...
# 3         Military, Comedy, Historical, Drama, Fantasy, ...
# 4         Military, Comedy, Historical, Drama, Fantasy, ...
# ...                                                     ...
# 57633273                      Action, Sci-Fi, Ecchi, Seinen
# 57633274                      Action, Sci-Fi, Ecchi, Seinen
# 57633275                     Mystery, Comedy, Kids, Fantasy
# 57633276  Comedy, Drama, Romance, School, Shounen Ai, Sl...
# 57633277                                               Kids
#
# [57633278 rows x 5 columns]

# %%
# only users with > 1000 ratings
df_reduced = df.groupby("user_id").filter(lambda x: len(x) > 1000)
df_reduced
# df_reduced.sort_values(by="user_id")
# Out:
#           user_id  anime_id  rating  \
# 42            326       430       9
# 61            446       430       7
# 121           853       430       8
# 124           890       430       6
# 133           943       430       7
# ...           ...       ...     ...
# 57633267   283786     45448       6
# 57633268   283786     42465       6
# 57633269   289506     41277       4
# 57633271   308285     40389       8
# 57633277   347134     39627       5
#
#                                                      Name  \
# 42        Fullmetal Alchemist: The Conqueror of Shamballa
# 61        Fullmetal Alchemist: The Conqueror of Shamballa
# 121       Fullmetal Alchemist: The Conqueror of Shamballa
# 124       Fullmetal Alchemist: The Conqueror of Shamballa
# 133       Fullmetal Alchemist: The Conqueror of Shamballa
# ...                                                   ...
# 57633267               Dou Hun Wei Zhi Xuan Yue Qiyuan IV
# 57633268                Guan Hai Ce Zhi Tie Qi Xiong Guan
# 57633269                                     Rainbow Ruby
# 57633271    Uchuu Senkan Yamato 2205: Aratanaru Tabidachi
# 57633277                        Nan-chan no Koutsuu Anzen
#
#                                                      Genres
# 42        Military, Comedy, Historical, Drama, Fantasy, ...
# 61        Military, Comedy, Historical, Drama, Fantasy, ...
# 121       Military, Comedy, Historical, Drama, Fantasy, ...
# 124       Military, Comedy, Historical, Drama, Fantasy, ...
# 133       Military, Comedy, Historical, Drama, Fantasy, ...
# ...                                                     ...
# 57633267                                    Action, Fantasy
# 57633268  Action, Military, Historical, Martial Arts, Fa...
# 57633269                                      Kids, Fantasy
# 57633271             Action, Military, Sci-Fi, Space, Drama
# 57633277                                               Kids
#
# [6711739 rows x 5 columns]

# %%
print(df_reduced["user_id"].value_counts())
print(df_reduced["Name"].value_counts())
# Out:
# 189037    15455
# 162615    14864
# 68042     13462
# 283786    12778
# 259790     9996
#           ...
# 306112     1001
# 106903     1001
# 157929     1001
# 247568     1001
# 198099     1001
# Name: user_id, Length: 4447, dtype: int64
# Angel Beats!                                               4078
# Sword Art Online                                           4028
# Shingeki no Kyojin                                         4011
# No Game No Life                                            3937
# Toradora!                                                  3921
#                                                            ...
# Jian Wang 3: Xia Gan Yi Dan Shen Jianxin Zhi Chang Piao       1
# Zetsumetsu Kigu-shun.                                         1
# Kaiketsu Zorori no Kyoufu no Hanayome Sakusen                 1
# Bite-Choicar                                                  1
# Nan-chan no Koutsuu Anzen                                     1
# Name: Name, Length: 16827, dtype: int64

# %%
# only animes with > 1000 ratings
df_reduced = df_reduced.groupby("Name").filter(lambda x: len(x) > 100)
df_reduced
# Out:
#           user_id  anime_id  rating  \
# 42            326       430       9
# 61            446       430       7
# 121           853       430       8
# 124           890       430       6
# 133           943       430       7
# ...           ...       ...     ...
# 57589782   351361      3175       5
# 57589783   351801      3175       6
# 57589784   352832      3175      10
# 57589785   352922      3175       2
# 57589786   352924      3175       7
#
#                                                      Name  \
# 42        Fullmetal Alchemist: The Conqueror of Shamballa
# 61        Fullmetal Alchemist: The Conqueror of Shamballa
# 121       Fullmetal Alchemist: The Conqueror of Shamballa
# 124       Fullmetal Alchemist: The Conqueror of Shamballa
# 133       Fullmetal Alchemist: The Conqueror of Shamballa
# ...                                                   ...
# 57589782               Kaitei Choutokkyuu: Marine Express
# 57589783               Kaitei Choutokkyuu: Marine Express
# 57589784               Kaitei Choutokkyuu: Marine Express
# 57589785               Kaitei Choutokkyuu: Marine Express
# 57589786               Kaitei Choutokkyuu: Marine Express
#
#                                                      Genres
# 42        Military, Comedy, Historical, Drama, Fantasy, ...
# 61        Military, Comedy, Historical, Drama, Fantasy, ...
# 121       Military, Comedy, Historical, Drama, Fantasy, ...
# 124       Military, Comedy, Historical, Drama, Fantasy, ...
# 133       Military, Comedy, Historical, Drama, Fantasy, ...
# ...                                                     ...
# 57589782           Action, Adventure, Comedy, Sci-Fi, Drama
# 57589783           Action, Adventure, Comedy, Sci-Fi, Drama
# 57589784           Action, Adventure, Comedy, Sci-Fi, Drama
# 57589785           Action, Adventure, Comedy, Sci-Fi, Drama
# 57589786           Action, Adventure, Comedy, Sci-Fi, Drama
#
# [6445588 rows x 5 columns]

# %%
print(df_reduced["user_id"].value_counts())
print(df_reduced["Name"].value_counts())
# Out:
# 189037    8767
# 162615    8400
# 68042     8301
# 291207    7774
# 283786    7616
#           ...
# 63105      809
# 289648     809
# 83662      806
# 66724      803
# 345858     559
# Name: user_id, Length: 4447, dtype: int64
# Angel Beats!                                                        4078
# Sword Art Online                                                    4028
# Shingeki no Kyojin                                                  4011
# No Game No Life                                                     3937
# Toradora!                                                           3921
#                                                                     ...
# Hakubutsushi                                                         101
# Sayokyoku                                                            101
# Flutter of Birds II: Tenshi-tachi no Tsubasa                         101
# Kujira (1952)                                                        101
# Tottoko Hamtarou Movie 2: Ham-Ham Hamuuja! Maboroshi no Princess     101
# Name: Name, Length: 9035, dtype: int64

# %%
df_reduced = df_reduced.sample(frac=0.1)
df_reduced
# Out:
#           user_id  anime_id  rating  \
# 42298664    24795      9063       5
# 33216260   330552     24833      10
# 34306085   148335     12679      10
# 46723917   189037     10810       7
# 1438952     78558     40221       6
# ...           ...       ...     ...
# 38633146   150528        53       5
# 54512715    53730     41207       7
# 11522721   168120     10611       3
# 45479348   308346      8740       7
# 50058325    34095     40295       8
#
#                                                        Name  \
# 42298664  Toaru Kagaku no Railgun: Entenka no Satsuei Mo...
# 33216260                                 Ansatsu Kyoushitsu
# 34306085                                          Joshiraku
# 46723917                                            Pucca 2
# 1438952                                         Kami no Tou
# ...                                                     ...
# 38633146                                      Ai Yori Aoshi
# 54512715  Tenioha! 2: Limit Over - Mada Mada Ippai, Ecch...
# 11522721                                               R-15
# 45479348             One Piece Film: Strong World Episode 0
# 50058325                                      Another World
#
#                                                      Genres
# 42298664                                      Comedy, Ecchi
# 33216260                    Action, Comedy, School, Shounen
# 34306085                     Slice of Life, Comedy, Shounen
# 46723917                    Action, Comedy, Parody, Romance
# 1438952          Action, Adventure, Mystery, Drama, Fantasy
# ...                                                     ...
# 38633146       Harem, Slice of Life, Comedy, Drama, Romance
# 54512715                                             Hentai
# 11522721              Comedy, Ecchi, Harem, Romance, School
# 45479348  Action, Adventure, Comedy, Fantasy, Shounen, S...
# 50058325                                             Sci-Fi
#
# [644559 rows x 5 columns]

# %%
# matrix = df_reduced.pivot_table(index="Name", columns="user_id", values='rating')
# matrix.head()

# %%
# print(matrix[353385].unique())
# # print(matrix[353387].unique())
# print(matrix[353398].unique())
# print(matrix[11].unique())

# %%
# Normalize matrix
# matrix_norm = matrix.subtract(matrix.mean(axis=1), axis='rows')
# matrix_norm.head()

# %%
# Pearson correlation
# user_sim = matrix_norm.T.corr()
# user_sim

# %%
# # Compute the user-item matrix
# user_item_matrix = df.pivot(index='user_id', columns='Name', values='rating')

# # Compute the Pearson correlation between users
# user_item_matrix = user_item_matrix.subtract(user_item_matrix.mean(axis=1), axis='rows')
# print(user_item_matrix)

# %%
user_item_matrix = df_reduced.pivot(index='user_id', columns='Name', values='rating')

# Compute the Pearson correlation between users
user_item_matrix = user_item_matrix.subtract(user_item_matrix.mean(axis=1), axis='rows')

user_corr = user_item_matrix.T.corr()

# %%
user_corr
# Out:
# user_id    326       446       478       781       853       890       912     \
# user_id
# 326      1.000000  0.174078  0.000000 -0.192961  0.419314 -0.210732  0.235702
# 446      0.174078  1.000000  0.221163       NaN       NaN  0.596559       NaN
# 478      0.000000  0.221163  1.000000  0.789076 -0.965909 -0.191462 -1.000000
# 781     -0.192961       NaN  0.789076  1.000000  0.132967 -0.600397  0.339121
# 853      0.419314       NaN -0.965909  0.132967  1.000000  0.362738       NaN
# ...           ...       ...       ...       ...       ...       ...       ...
# 352922  -1.000000       NaN  1.000000 -1.000000       NaN  0.717532       NaN
# 352924  -0.674200  0.646997 -0.054554       NaN -0.332650  0.710431 -0.082199
# 352930   0.540062  0.810093  0.285056  0.000000  0.324937 -1.000000       NaN
# 353304  -0.866025  0.688247  0.676716  0.821995       NaN  0.728705       NaN
# 353325  -0.058926       NaN  0.523723 -0.359211 -1.000000  0.000000       NaN
#
# user_id    943       985       1177    ...    352660    352669        352761  \
# user_id                                ...
# 326     -0.520416  0.324967  0.592014  ...  0.740959  0.659912 -4.532467e-17
# 446           NaN -0.522233  1.000000  ...  0.774597  0.476731  4.166667e-01
# 478      0.556030 -1.000000  0.539951  ...       NaN -0.200446 -7.071068e-01
# 781     -0.719569  0.575224  0.746091  ...  0.975980       NaN  4.622502e-02
# 853           NaN -0.055863 -0.345547  ...       NaN -0.041703  9.597599e-01
# ...           ...       ...       ...  ...       ...       ...           ...
# 352922        NaN       NaN       NaN  ...       NaN  0.831522  9.971765e-01
# 352924        NaN  0.777778  0.555556  ...       NaN  0.211289  9.538210e-01
# 352930        NaN       NaN  0.389249  ...  0.755929  0.801784  7.307981e-01
# 353304        NaN -0.547723  0.944911  ...  0.804030       NaN  3.144855e-01
# 353325        NaN -0.174078 -0.816497  ...       NaN -1.000000  1.000000e+00
#
# user_id        352832    352835  352922    352924    352930    353304  \
# user_id
# 326      4.504401e-17  0.944911    -1.0 -0.674200  0.540062 -0.866025
# 446               NaN  0.405999     NaN  0.646997  0.810093  0.688247
# 478     -6.808829e-01  0.666667     1.0 -0.054554  0.285056  0.676716
# 781     -1.456929e-01  0.812158    -1.0       NaN  0.000000  0.821995
# 853      7.205767e-01 -0.103807     NaN -0.332650  0.324937       NaN
# ...               ...       ...     ...       ...       ...       ...
# 352922            NaN       NaN     1.0  0.500000       NaN -0.500000
# 352924   9.819805e-01 -0.648886     0.5  1.000000  0.174078  0.468521
# 352930   5.833333e-01  1.000000     NaN  0.174078  1.000000 -0.707107
# 353304            NaN  0.143088    -0.5  0.468521 -0.707107  1.000000
# 353325  -1.000000e+00 -1.000000     NaN       NaN  0.316228       NaN
#
# user_id    353325
# user_id
# 326     -0.058926
# 446           NaN
# 478      0.523723
# 781     -0.359211
# 853     -1.000000
# ...           ...
# 352922        NaN
# 352924        NaN
# 352930   0.316228
# 353304        NaN
# 353325   1.000000
#
# [4447 rows x 4447 columns]

# %%
# Sort the correlations in descending order and select the top n similar users
# similar_users = user_corr[24795].sort_values(ascending=False)[1:10+1].index.tolist()

# %%
import pandas as pd
import numpy as np
from sklearn.utils import shuffle
import operator

def recommend_animes(df, user_id, n_similar_users, n_animes_to_recommend):
    
    
    # Sort the correlations in descending order and select the top n similar users
    similar_users = user_corr[user_id].sort_values(ascending=False)[1:n_similar_users+1].index.tolist()
    # print("SIMILAR  - \n", similar_users, "\n-------------------\n")
    # Compute the weighted average of the ratings for each anime using the similar users' ratings
    anime_ratings = {}
    for anime_id in user_item_matrix.columns:
        # print("ANIME - " , anime_id, "\n")
        total = 0
        count = 0

        # print(user_item_matrix.loc[user_id, anime_id])
        if user_item_matrix.loc[user_id, anime_id] == np.nan:
            anime_ratings[anime_id] = np.nan
        else:
            
            for user in similar_users:
                if( not pd.isna(user_item_matrix[anime_id][user])):
                    total += user_item_matrix[anime_id][user] * user_corr[user][user_id]
                    count +=1
            if(count != 0):
                anime_ratings[anime_id] = total/count
                          
            # print(user_item_matrix.loc[similar_users, anime_id].dropna())
            # print("----------------------------------\n")
            # print(user_corr[similar_users])
            # anime_ratings[anime_id] = np.average(user_item_matrix.loc[similar_users, anime_id].dropna(), 
                                            #  weights=user_corr[similar_users])
            # anime_ratings.append(np.average(user_item_matrix.loc[similar_users, anime_id].dropna(), 
            #                                  weights=user_corr[similar_users]))
    
    # Convert the anime_ratings list into a Pandas Series
    # anime_ratings = pd.Series(anime_ratings, index=user_item_matrix.columns)
    
    # Sort the anime ratings in descending order and select the top n animes to recommend
    top_animes = sorted(anime_ratings.items(), key=operator.itemgetter(1), reverse=True)[:n_animes_to_recommend]
    # anime_ratings.sort_values(ascending=False)[:n_animes_to_recommend]
    
    # Return the top animes with their predicted ratings
    return top_animes

# %%
# Load the data into a Pandas DataFrame
df = df_reduced

# Call the recommend_animes function to get the top recommended animes for a given user
user_id = 283786 # 24795
n_similar_users = 1
n_animes_to_recommend = 20
top_animes = recommend_animes(df, user_id, n_similar_users, n_animes_to_recommend)

# Print the top recommended animes with their predicted ratings
top_animes
# Out:
# [('Amagami SS', 3.0884955752212386),
#  ('Ane Yome Quartet', 3.0884955752212386),
#  ('Baku Ane 2: Otouto Ippai Shibocchau zo! The Animation', 3.0884955752212386),
#  ('Kami nomi zo Shiru Sekai II', 3.0884955752212386),
#  ('Mahouka Koukou no Rettousei', 3.0884955752212386),
#  ('Mashiro-iro Symphony: The Color of Lovers', 3.0884955752212386),
#  ('Muttsuri Dosukebe Tsuyu Gibo Shimai no Honshitsu Minuite Sex Sanmai',
#   3.0884955752212386),
#  ('Sweet Home: H na Oneesan wa Suki Desu ka?', 3.0884955752212386),
#  ('Chichiiro Toiki', 2.0884955752212386),
#  ('Chrome Shelled Regios', 2.0884955752212386),
#  ('Cool Devices', 2.0884955752212386),
#  ('Inma Youjo', 2.0884955752212386),
#  ('Jewelry The Animation', 2.0884955752212386),
#  ('Koiito Kinenbi The Animation', 2.0884955752212386),
#  ('Kyonyuu Princess Saimin', 2.0884955752212386),
#  ('Oni Chichi: Re-birth', 2.0884955752212386),
#  ('Residence', 2.0884955752212386),
#  ('Serial Experiments Lain', 2.0884955752212386),
#  ('Ane Koi: Suki Kirai Daisuki.', 1.0884955752212386),
#  ('Dorei Usagi to Anthony The Animation', 1.0884955752212386)]

# %%
user_item_matrix["Amagami SS"].value_counts()
# Out:
#  1.119658    2
#  0.192771    1
#  2.980769    1
#  0.481481    1
# -0.527132    1
#             ..
#  1.317518    1
#  0.367470    1
# -0.897436    1
# -1.321101    1
#  0.823009    1
# Name: Amagami SS, Length: 251, dtype: int64
